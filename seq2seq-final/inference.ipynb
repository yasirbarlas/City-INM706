# %% [markdown]
# # INM706: Inference (Seq2Seq)
#
# This is notebook is for inference of the models found in the [City-INM706](https://github.com/yasirbarlas/City-INM706) Github repository.
#
# The model used for inference here is our improved/final model, and so the parameters reflect this.

# %% [markdown]
# ### Import Libraries and Models

# %%
# Import relevant libraries and models

from models import *
from dataset import *

import random
import numpy as np
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from nltk.translate.nist_score import sentence_nist

# %% [markdown]
# ### Create Model From Checkpoint

# %%
# Set device
device = torch.device("cpu")
if torch.cuda.is_available():
    device = torch.device("cuda")

# Get model checkpoint
model = torch.load(f"checkpoints/checkpoint_seq2seq_latest.pth", map_location = device)

# Encoder and Decoder, replace 128 with your hidden dimension size and other parameters
# The parameters given are for our improved/final model
encoder = EncoderRNN(model["input_lang"].n_words, 128, bidirectional = True, num_layers = 2, layer_norm = True, dropout_p = 0.1).to(device)
decoder = DecoderRNN(128, model["output_lang"].n_words, num_layers = 2, use_lstm = True, max_seq_len = 50).to(device)

# Split into Encoder and Decoder
encoder.load_state_dict(model["encoder_state_dict"])
decoder.load_state_dict(model["decoder_state_dict"])

# Ensure the Encoder and Decoder are in evaluation mode
encoder.eval()
decoder.eval()
# Out:
# DecoderRNN(
#   (embedding): Embedding(96093, 128)
#   (lstm): LSTM(128, 128, num_layers=2, batch_first=True)
#   (out): Linear(in_features=128, out_features=96093, bias=True)
# )

# %% [markdown]
# ### Test Dataset

# %%
# Make test dataset (change max_seq_len to your maximum sentence word length)
# Choose any dataset by inserting their paths as below (or skip if not interested in model testing)
test_dataset = TranslationDataset(lang1 = "test2008-en.txt", lang2 = "test2008-fr.txt", max_seq_len = 50, reverse = False, directory = "../fr-en/")
# Out:
# Read 2000 sentence pairs
# Trimmed to 1766 sentence pairs
# Counting words...
# Counted words:
# test2008-en.txt 5003
# test2008-fr.txt 5924

# %% [markdown]
# ### Functions for Inference
#
# These functions are necessary to display sentences in human speech, rather than in tokens.

# %%
# Functions for inference

def indexesFromSentence(lang, sentence):
    return [lang.word2index[word] for word in sentence.split(" ") if word in lang.word2index]

def tensorFromSentence(lang, sentence):
    EOS_token = 1
    indexes = indexesFromSentence(lang, sentence)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype = torch.long, device = device).view(1, -1)

def evaluate(encoder, decoder, sentence, input_lang, output_lang):
    EOS_token = 1
    with torch.no_grad():
        input_tensor = tensorFromSentence(input_lang, sentence)

        encoder_outputs, encoder_hidden = encoder(input_tensor)
        decoder_outputs, decoder_hidden, decoder_attn = decoder(encoder_outputs, encoder_hidden)

        _, topi = decoder_outputs.topk(1)
        decoded_ids = topi.squeeze()

        decoded_words = []
        for idx in decoded_ids:
            if idx.item() == EOS_token:
                decoded_words.append("<EOS>")
                break
            decoded_words.append(output_lang.index2word[idx.item()])
    return decoded_words, None

def evaluateDataset(encoder, decoder, dataset, model):
    bleus = []
    nists = []
    skipped = 0

    for pair in dataset.pairs:
        # Check if all words in the input sentence exist in the input_lang word2index
        input_valid = all(word in model["input_lang"].word2index for word in pair[0].split())

        if not input_valid:
            skipped += 1
            #print(f"Skipped sentence due to unknown words: {pair[0]} -> {pair[1]}")
            continue

        print(">", pair[0])
        print("=", pair[1])
        output_words, _ = evaluate(encoder, decoder, pair[0], model["input_lang"], model["output_lang"])
        output_sentence = " ".join(output_words)
        print("<", output_sentence)

        # BLEU
        ref = [pair[1].split()]
        bleu = sentence_bleu(ref, output_sentence.split()[:-1], smoothing_function = SmoothingFunction().method1)
        nist = sentence_nist(ref, output_sentence.split()[:-1], min(4, len(output_sentence.split()[:-1])))
        bleus.append(bleu)
        nists.append(nist)
        print("BLEU Score", bleu)
        print("NIST Score", nist)
        print("")

    if bleus:
        print("Average BLEU Score:", np.mean(bleus))
    if nists:
        print("Average NIST Score:", np.mean(nists))
    print(f"Total skipped sentences: {skipped}")

# %% [markdown]
# ### Test Set Evaluation
#
# Calculate BLEU and NIST for the test set imported earlier.

# %%
# Test Dataset Results
evaluateDataset(encoder, decoder, test_dataset, model)
# Out:
# > these are as we know very tricky negotiations and raise fears of a setback or a watered down agreement in nice which as you have already acknowledged mr moscovici would be even more serious
# = ces negociations nous le savons sont tres difficiles et font craindre un echec ou un accord a minima a nice ce qui serait encore plus grave vous en avez deja convenu monsieur le ministre
# < nous savons que nous avons des negociations et des negociations tres difficiles comme un exemple de partialite et de desaccord avec l accord de nice qui est encore plus important que l accord de nice <EOS>
# BLEU Score 0.020904996083879822
# NIST Score 1.7157015455715454
#
# > any other procedure would mean a huge democratic deficit
# = toute autre facon de faire entrainerait un deficit democratique majeur
# < un autre rapport pourrait etre un peu transparent <EOS>
# BLEU Score 0.025725069574826766
# NIST Score 0.6732186484917868
#
# > mr president mr president of the commission mr president in office ladies and gentlemen i should like to thank the european parliament delegation in the convention and the president of the convention mr roman herzog for their committed work
# = monsieur le president monsieur le president prodi monsieur le president du conseil mes chers collegues je remercie la delegation du parlement europeen a la convention et le president de celle ci roman herzog pour leur travail engage
# < monsieur le president monsieur le president de la commission mesdames et messieurs je voudrais remercier la vice presidente de la convention de m lehne et de m klaus heiner lehne et de la chambre parlementaire europeen pour son travail <EOS>
# BLEU Score 0.16806683918252788
# NIST Score 1.9496593168125942
#
# > on this issue i would like to indicate if not my disagreement then at least some slight differences in opinion on two points
# = mais la dessus je voudrais marquer sinon un desaccord du moins des nuances sur deux points
# < a ce sujet je voudrais dire que je ne partage pas la position de m bertens dans deux points qui sont contradictoires <EOS>
# BLEU Score 0.027472210590938562
# NIST Score 0.9090909090909091
#
# > he was quite right to emphasise the distance we have travelled since the fall of the wall and the reunification of germany ten years ago
# = il a eu raison de souligner le chemin parcouru depuis la chute du mur et la reunification allemande il y a dix ans
# < il a ete tres important de dire que nous avons eu le rideau de fer et nous avons aboli la date de la chute de la deuxieme version de l allemagne <EOS>
# BLEU Score 0.022095731396358693
# NIST Score 1.2509265893928962
#
# > she also made an extremely worthwhile suggestion concerning the link between the charter and discussions over a future article
# = elle a aussi fait une suggestion extremement interessante concernant le lien entre la charte et la discussion sur un eventuel article
# < elle a egalement exprime une suggestion de la commission d inclure dans l esprit d un accord sur l internet et l autre l article du traite <EOS>
# BLEU Score 0.02556795749489219
# NIST Score 1.427068770555883
#
# > this is a feasible undertaking and the university of florence s study would serve as an excellent basis from which to start work
# = ce travail est possible et l etude menee par l institut universitaire de florence constitue une excellente base pour l effectuer de maniere efficace
# < une telle evaluation et l emploi de la commission industrielle sont un exemple de l institut europeen pour l emploi <EOS>
# BLEU Score 0.03195992775194228
# NIST Score 1.5723523245813502
#
# > in saying this mr moscovici i have no intention of giving the community total control
# = ici monsieur moscovici je ne pense pas que l on doive passer du tout communautaire
# < en resume m moscovici a demande de ne pas exercer une surveillance totale <EOS>
# BLEU Score 0.017532201649672802
# NIST Score 0.827014184562951
#
# > now however we are seeing that president putin is pursuing a policy of openness towards the west
# = a present cependant nous observons que le president poutine pratique une politique d ouverture a l occident
# < toutefois nous constatons que le president poutine a toujours fait une politique de paix a l egard de l occident <EOS>
# BLEU Score 0.1835554260049945
# NIST Score 2.2007361416350557
#
# > report a by mr skinner on behalf of the committee on economic and monetary affairs on the commission communication risk capital implementation of the action plan proposals for moving forward com c cos
# = rapport a de m skinner au nom de la commission economique et monetaire sur la communication de la commission intitulee le capital investissement propositions visant a poursuivre la mise en uvre du plan d action com c cos
# < rapport a de m von wogau au nom de la commission economique et monetaire sur les mesures de communication sur les licenciements dans les projets de mise en uvre des mesures de la commission sur la mise en uvre des mesures de la commission <EOS>
# BLEU Score 0.3240015881743024
# NIST Score 2.5176999343186197
#
# > is this not a case of double standards ?
# = n y a t il pas ici deux poids deux mesures ?
# < est ce que l ue legifere en matiere de dereglementation <EOS>
# BLEU Score 0
# NIST Score 0.0
#
# > piecyk recommendation for second reading a
# = recommandation pour la deuxieme lecture piecyk a
# < une recommandation a par exemple adoptee par le rapport lange <EOS>
# BLEU Score 0.025098621243978974
# NIST Score 0.5614709844115209
#
# > at the same time introducing larger buses would make it possible to reduce the number of buses on the road thereby reducing damage to the environment
# = dans le meme temps l introduction de bus de plus grandes dimensions permettrait de reduire le nombre des bus en circulation ce qui nuirait moins a l environnement
# < en meme temps les vehicules utilitaires legers pourraient reduire les emissions de gaz a effet de serre et de reduire considerablement la vie des travailleurs <EOS>
# BLEU Score 0.024610891548598097
# NIST Score 1.5218142185384755
#
# > to risk personal capital in particular is a highly precarious business
# = risquer son capital propre est une activite tres dangereuse
# < il est vrai que le service d un haut niveau de vie est particulierement precaire <EOS>
# BLEU Score 0.013217947626377298
# NIST Score 0.2113283334294875
#
# > it is quite specific on the other hand regarding the right to property and freedom to conduct a business affecting primarily the capital owning minority the right to exercise this and to abuse it
# = elle est en revanche precise sur le droit de propriete sur la liberte d entreprise qui concernent surtout la minorite qui possede des capitaux le droit d en user et d en abuser
# < il s agit d une question qui concerne specifiquement le droit de droit et de droit de propriete intellectuelle et de la liberte d expression et de justice a la fois pour les entreprises et a leur propre ordre de responsabilite <EOS>
# BLEU Score 0.05216691004954023
# NIST Score 1.3283923532229556
#
# > mr president i abstained from the vote on the resolution on the charter of fundamental rights of the european union because i consider that this charter is still extremely unsatisfactory despite some progress
# = monsieur le president je me suis abstenu lors du vote sur la resolution concernant la charte des droits fondamentaux de l union europeenne parce que je trouve cette charte encore tres insatisfaisante malgre quelques avancees
# < monsieur le president je me suis abstenu de voter sur la charte des droits fondamentaux de l union europeenne car je suis particulierement decu par la charte de l egalite des chances car je suis certain que nous n avons pas encore ete tres satisfaits <EOS>
# BLEU Score 0.32802304154154927
# NIST Score 2.556482026842579
#
# > the csu s europe group supports the horizontal provision which makes it clear that no new powers are being established for the community or the union
# = le groupe csu au parlement europeen est favorable a la disposition horizontale qui etablit qu aucune nouvelle competence n est creee pour la communaute et pour l union
# < le groupe socialiste europeen ne soutient pas l idee d une nouvelle definition de l egalite des chances qui est clairement definie par l union europeenne ou la commission europeenne <EOS>
# BLEU Score 0.022872196013470604
# NIST Score 1.3755398099506146
#
# > because we think that the process of european integration warrants a genuine democratic public debate there can be no political construction of europe without social rights or democracy
# = parce que nous pensons que le processus constituant de l europe merite un vrai debat public et democratique il ne peut y avoir de construction politique de l europe sans droits sociaux et sans democratie
# < parce que nous pensons que le processus democratique europeen ne peut etre un debat democratique sans une politique europeenne sans que les citoyens ne soient des democraties et des droits de l homme ou de la democratie <EOS>
# BLEU Score 0.2145714928680254
# NIST Score 2.7351833883522185
#
# > that concludes the vote
# = le vote est clos
# < l heure des votes aura lieu a l heure actuelle <EOS>
# BLEU Score 0
# NIST Score 0.0
#
# > a by mr poos on cyprus com c cos
# = a de m poos sur chypre com c cos
# < un rapport de m poos a ete invoque par la presidence allemande <EOS>
# BLEU Score 0.09058752341587764
# NIST Score 1.0566416671474375
#
# > i am convinced that some countries will be in a position to prepare themselves adequately within that time
# = je suis convaincu que certains pays seront en mesure d operer les preparatifs suffisants dans ce laps de temps
# < je suis convaincu que certains pays seront prets a adopter cette question dans le cadre de cette periode <EOS>
# BLEU Score 0.32941646362215893
# NIST Score 2.0979465840567224
#
# > the french presidency will immediately inform the committee which you chair mr brok of the result of these negotiations come tuesday afternoon according to the tradition that has developed between us
# = la presidence francaise informera immediatement la commission que vous presidez monsieur brok du resultat de ces negociations des le mardi apres midi comme c est desormais la coutume entre nous
# < la presidence francaise de la commission de la commission de l union europeenne a fait part de l avis de m hansch a l occasion de la reunion de negociation de la presidence allemande et je suis d accord avec vous pour le succes de ces negociations <EOS>
# BLEU Score 0.0400375921574034
# NIST Score 1.1161647971073911
#
# > we in fact expect in absolute agreement with commissioner verheugen to enter into negotiations on new chapters i e between and according to country just like the portuguese presidency before us
# = nous comptons en effet en parfait accord avec le commissaire verheugen engager les negociations sur nouveaux chapitres ce qui veut dire de a selon les pays tout comme la presidence portugaise avant nous
# < en fait nous attendons de l accord avec le conseil de ministres des negociations avec les pays candidats a l adhesion a l avenir de la slovaquie et de la presidence francaise qui est en accord avec les autres collegues <EOS>
# BLEU Score 0.04066870399856362
# NIST Score 1.7922888204004455
#
# > the date of january which is the only one on which the european union has agreed is however both for the candidates and for ourselves an extremely ambitious objective and this is the deadline to which the presidency will be working
# = mais la date du er janvier qui est la seule dont l union soit convenue constitue pour les candidats comme pour nous un objectif extremement ambitieux et c est dans cette perspective que la presidence va mobiliser tous ses efforts
# < la date de l adhesion de l union europeenne a ete fixee a l heure actuelle a l heure actuelle et nous ne voulons pas que les delais fixes soient respectes et que nous soyons prets a faire en sorte que la presidence soit prete a l europe <EOS>
# BLEU Score 0.03115557772802626
# NIST Score 1.2210136303449506
#
# > i am quite ready of course to follow the very important debate we are all involved in here today
# = je suis tout pret bien sur a suivre le debat tres important qui nous reunit aujourd hui
# < je suis tout a fait d accord avec ce debat tres important pour nous tous aujourd hui <EOS>
# BLEU Score 0.11502783619900048
# NIST Score 2.4043899066178476
#
# > the present and largest enlargement round in the history of european unification is a morally imperative strategically needed and politically feasible move
# = l elargissement en cours le plus important dans l histoire de l unification europeenne est moralement souhaitable strategiquement necessaire et politiquement realisable
# < l un ou l autre elargissement a l ere de l elargissement de l union europeenne est un tabou politique et une politique europeenne moderne et de maniere a pouvoir etre determinee a se sentir forte <EOS>
# BLEU Score 0.020298407172594946
# NIST Score 0.9041892386259391
#
# > when we see that the countries in the enlargement process have already stabilised their democratic systems in a short space of time then that is their achievement
# = si nous pouvons constater que les pays engages dans le processus d elargissement ont deja atteint dans un delai tres bref la stabilite de leurs systemes democratiques c est la une performance que ces peuples ont accompli d eux memes
# < lorsque nous avons constate que les processus de stabilisation du marche interieur ont deja ete crees dans les pays candidats a la construction de ces conditions <EOS>
# BLEU Score 0.018074425478151045
# NIST Score 0.9958837214441715
#
# > they are also intended to help the eu institutions monitor their success and to act as a basis on which negotiating strategies can be further developed
# = pour les institutions de l ue ils doivent servir a controler le succes du processus et a poursuivre le developpement des strategies de negociation
# < elles sont egalement censees contribuer a renforcer les institutions europeennes et les institutions de l ue qui peuvent se poursuivre dans la phase de negociation <EOS>
# BLEU Score 0.17729842264695017
# NIST Score 1.797318333621796
#
# > mr president minister commissioner ladies and gentlemen today we are debating mr brok s report on the progress made on the european union s enlargement process an annually recurring theme
# = monsieur le president monsieur le ministre monsieur le commissaire chers collegues nous discutons aujourd hui du rapport brok consacre au progres du processus d elargissement de l union europeenne un sujet qui revient chaque annee
# < monsieur le president monsieur le commissaire chers collegues le rapport brok a ete debattu en faveur du rapport de m megahy sur l elargissement de l union europeenne dans le cadre de l union europeenne <EOS>
# BLEU Score 0.31217188619742475
# NIST Score 2.455074580202313
#
# > an essential part of the report is paragraph and the amendment which my group tabled in relation to it
# = a nos yeux le paragraphe et l amendement qu a depose mon groupe a ce sujet sont essentiels
# < un point fondamental est le rapport de mon groupe et de l amendement qui est le rapport de mon collegue <EOS>
# BLEU Score 0.03187271473320672
# NIST Score 1.2509775004326937
#
# > mr president mr brok s report is an excellent description of the european parliament s position
# = monsieur le president le rapport de notre collegue brok constitue une excellente description de la position du parlement europeen
# < monsieur le president le rapport de m brok est tres interessant <EOS>
# BLEU Score 0.23188918537888742
# NIST Score 0.7465896080079012
#
# > the critical thing is not to allow frustration to grow among the candidates that they are always in the anteroom but never quite in the chamber
# = l important est de ne pas laisser monter la frustration parmi les pays candidats qui rappelons le meme s ils attendent dans l antichambre ne sont pas encore entres de plain pied dans l union
# < la critique ne tient pas compte de la frustration des candidats a l adhesion de l union meme si elle ne se trouve pas encore a le dire <EOS>
# BLEU Score 0.024091881587603038
# NIST Score 2.0396187873526506
#
# > our group believes that it is quite possible if we are so determined to include the first group of applicant countries already in the next european parliamentary elections if there is determination on both sides to do so
# = notre groupe considere qu en agissant de facon determinee il est tout a fait possible que le premier groupe puisse adherer au moment des prochaines elections du parlement europeen mais il faut agir de facon decidee de part et d autre
# < notre groupe pense que le premier pays a ete possible pour les pays candidats a l adhesion a l union europeenne qui a deja ete prise en consideration par les groupes politiques qui seront egalement appeles a faire des elections <EOS>
# BLEU Score 0.03335381164369726
# NIST Score 1.3110134341549613
#
# > our disagreements with a portion of mr brok s report range from points of detail to others of greater importance
# = les divergences concernant ce qui est affirme dans le rapport brok concernent aussi bien des details que des points plus importants
# < nos points de vue de m brok concernant le rapport de m brok et d autres points sont tres sensibles a l ensemble des autres <EOS>
# BLEU Score 0.021084454569051277
# NIST Score 1.0141561814669025
#
# > on all these subjects the brok report confines itself to discussing adaptation and reform
# = sur tous ces sujets le rapport brok se borne a parler d adaptation de reformes
# < ce rapport a deja ete aborde dans les traites de bruxelles et de la question de l elargissement et de ses exigences politiques <EOS>
# BLEU Score 0.010900096978029118
# NIST Score 0.5095944255141546
#
# > unmistakably the personal commitment of the rapporteurs of the committee on foreign affairs human rights common security and defence policy and the productive exchange of ideas in those circles point in the same direction
# = l implication personnelle des rapporteurs de la commission des affaires etrangeres des droits de l homme de la securite commune et de la politique de defense ainsi que les echanges de point de vue fertiles qui y ont eu lieu vont immanquablement dans la meme direction
# < bien que les relations de la commission sur le rapport de mme la russa et de la politique etrangere de la defense des droits de l homme et de la cooperation avec les autres institutions <EOS>
# BLEU Score 0.1730328356902749
# NIST Score 2.0821395496507575
#
# > enlargement as i have just said is a historic process a duty
# = l elargissement je viens de le dire c est un processus historique c est un devoir
# < l elargissement qui est un evenement historique est un processus de decision <EOS>
# BLEU Score 0.0945380603824307
# NIST Score 2.0158460630408346
#
# > the european union s credibility is implicated in this
# = il en va de la credibilite de l union
# < la credibilite de l union europeenne est donc a cet egard <EOS>
# BLEU Score 0.3508439695638686
# NIST Score 1.4499659097465059
#
# > let us create the conditions for success for it is important that this enlargement is not a flash in the pan not just a symbolic decision that will go on to create problems
# = creons nous les conditions de la reussite car il est important que cet elargissement ne soit pas une flambee que cet elargissement ne soit pas seulement une decision symbolique qui ensuite creera des problemes
# < creons un cadre de paix historique pour l elargissement ne peut etre pas une realite historique mais nous ne devons pas perdre de vue les possibilites de l europe <EOS>
# BLEU Score 0.02048357963418464
# NIST Score 1.422930889365858
#
# > we have already done this to the widest extent
# = nous en disposons deja tres largement
# < cette proposition a ete adoptee par une autre maniere d agir <EOS>
# BLEU Score 0
# NIST Score 0.0
#
# > before i was born freedom and democracy had triumphed over oppression and the insanity of war and a european union was being formed
# = avant que je ne naisse la liberte et la democratie avaient eu le dessus sur l oppression et la folie de la guerre et une union europeenne s etait constituee
# < avant la liberte et la liberte de la democratie ont ete libres de la guerre et de l opportunisme de la constitution de l union europeenne et de la liberte <EOS>
# BLEU Score 0.1954598432860746
# NIST Score 2.255350053504137
#
# > they possess a rich source of culture diversity and potential which the united europe cannot do without
# = ces pays sont une source abondante de culture de diversite et de possibilites multiples dont l europe unifiee ne saurait se passer
# < ils sont une source de richesse et de richesse de l europe qui ne peuvent pas etre atteints par la communaute <EOS>
# BLEU Score 0.0692652584592428
# NIST Score 1.8798845837384512
#
# > if it completes the negotiations effectively and purposefully estonia has a good chance of becoming one of the union s new member states
# = si l estonie sait adopter au cours des negociations une demarche efficace et ciblee elle aura de bonnes chances de devenir l un des nouveaux etats membres de l union
# < si l on a acheve les frontieres et les preparatifs de l union europeenne il est possible de trouver une solution a l ancienne republique yougoslave de macedoine <EOS>
# BLEU Score 0.04628076097107137
# NIST Score 1.4998265619909241
#
# > the critical comments and the proposals in my report for urgently needed progress in administrative and social reform are designed to bring latvia quickly and successfully into the european union
# = les critiques et propositions formulees dans mon rapport quant a des progres urgents et necessaires en matiere administrative et sociale visent uniquement a conduire rapidement et avec succes la lettonie dans l union europeenne
# < les propositions et mes collegues ont souligne que le rapport de m tsatsos a besoin de reformes structurelles concretes et de la necessite de reformes structurelles et de la bulgarie et de la communaute europeenne <EOS>
# BLEU Score 0.009444898173424886
# NIST Score 1.1964179546429543
#
# > it is our job to continue to support latvia with the integration of the russian population
# = il est de notre devoir de continuer d appuyer la lettonie sur la question de l integration de la population russe
# < c est notre mission de la croatie a l ukraine en faveur de la lituanie <EOS>
# BLEU Score 0.025628355757049314
# NIST Score 1.0638110162631085
#
# > the fact that the lithuanian currency is still pegged to the dollar is also important here because as the dollar rises so too does the value of the litas against the euro
# = le lien encore existant entre la devise lituanienne et le dollar joue egalement un role en la matiere car le litas suit la hausse du dollar par rapport a l euro cela provoque un recul des contrats d exportation de lituanie vers la zone euro
# < le fait que le dollar de la banque centrale europeenne soit egalement dit dollar parce que nous devons egalement faire la difference entre le dollar et la pologne <EOS>
# BLEU Score 0.012113167729718294
# NIST Score 0.7574613843682967
#
# > that is the only way of giving kaliningrad a chance to improve its development potential
# = c est la seule possibilite d ameliorer les possibilite de developpement pour kaliningrad egalement
# < ce n est que de la possibilite de contribuer a l enrichissement de l enrichissement pacifique <EOS>
# BLEU Score 0.030934588294313718
# NIST Score 0.9560053971810676
#
# > many of us feel that it would have been a good idea to specify the dates for accession in order to encourage the countries and give them a sense of our continuing support
# = nombre d entre nous pensent que pour stimuler et maintenir cet appui vivant il aurait ete utile d indiquer des dates pour l adhesion
# < nous avons beaucoup d avis que nous avons d autres possibilites de voir les pays candidats et nous devons encourager l adhesion a l esprit et a promouvoir les bonnes conditions de cette initiative <EOS>
# BLEU Score 0.01583610518564545
# NIST Score 0.8851393383837677
#
# > one problem specific to the czech republic especially on the german czech border is the problem of prostitution especially child prostitution
# = un probleme particulier auquel est confronte la republique tcheque notamment a la frontiere avec l allemagne est celui de la prostitution en particulier de la prostitution enfantine
# < un exemple de la belgique de la pologne est la question de la belgique de l allemagne de l est de la finlande dans le domaine de la prostitution et de la prostitution forcee dans le domaine de l immigration clandestine <EOS>
# BLEU Score 0.04809089118277273
# NIST Score 1.2161838421493927
#
# > we are in the middle of the negotiating process
# = nous sommes au milieu d un processus de negociations
# < le processus de negociation est donc ouvert <EOS>
# BLEU Score 0.05249325939883762
# NIST Score 0.6939578160701716
#
# > the problems i mentioned are not insurmountable
# = les problemes que je vous ai cites ne sont pas insurmontables
# < le rapport crowley a egalement ete aborde <EOS>
# BLEU Score 0
# NIST Score 0.0
#
# > these policies must lead to the free and unforced assimilation of individuals belonging to the gypsy community
# = ces politiques doivent mener a une assimilation libre non forcee des individus appartenant a cette communaute
# < ces politiques doivent etre libres et de la citoyennete de l europe de la vie de leurs familles <EOS>
# BLEU Score 0.053463162573637084
# NIST Score 0.6666666666666666
#
# > the current resolution and report focus on certain of the more controversial issues namely nuclear safety border controls the treatment of minorities and the question of corruption
# = la resolution et le rapport qui nous concernent se focalisent sur certaines des questions les plus controversees a savoir la securite nucleaire les controles frontaliers le traitement des minorites et le probleme de la corruption
# < la resolution du conseil et de la resolution contient des questions specifiques concernant les questions relatives a la securite des frontieres exterieures et a la securite des minorites ethniques et de l isolement des frontieres exterieures <EOS>
# BLEU Score 0.026526726488604817
# NIST Score 1.871464218872409
#
# > perhaps it is no coincidence that those same public polls show that the european union ambassador is the second most popular person in romania today
# = peut etre n est ce pas une coincidence que ce meme sondage public revele que l ambassadeur aupres de l union europeenne est la deuxieme personnalite la plus populaire en roumanie aujourd hui
# < ce n est pas surprenant que les citoyens de l union europeenne reconnaissent que la commission europeenne peut egalement etre consideree comme un exemple de la population de la societe de l est <EOS>
# BLEU Score 0.10684784705760664
# NIST Score 2.2042895730222805
#
# > perpetuation of the status quo following the turkish invasion of july august is not acceptable to the european union
# = la perpetuation du status quo issue de l invasion turque de juillet aout n est pas acceptable pour l union europeenne
# < une conclusion de l accord de readmission entre le gouvernement turc l union europeenne a ete rejete par la cour de cause n a pas ete abolie <EOS>
# BLEU Score 0.050317476265301385
# NIST Score 1.3928807363678488
#
# > it was only logical for the european council in helsinki in december last year to give the green light for the resumption of accession negotiations with malta when the accession negotiations were extended
# = il n etait que logique que le conseil europeen d helsinki en decembre de l annee derniere ait donne son feu vert dans le contexte de l extension des negociations d adhesion a la reprise des negociations avec malte
# < ce n est que le conseil europeen de decembre a helsinki a l automne de l annee derniere a l occasion de l adhesion des pays candidats a l adhesion a l occasion de l adhesion des negociations d adhesion a l union europeenne <EOS>
# BLEU Score 0.20586736678432452
# NIST Score 2.218958166440642
#
# > he has the express support of our committee there
# = sur ce point il a le soutien total de notre commission
# < ce rapport a egalement ete reserve a la commission <EOS>
# BLEU Score 0.025271148634948993
# NIST Score 0.9730810182559247
#
# > allow me to comment on a few focal points
# = permettez moi d aborder quelques elements prioritaires
# < l opinion de certains autres points de vue sur le contenu de son contenu <EOS>
# BLEU Score 0
# NIST Score 0.0
#
# > hence if we are to be honest we cannot keep setting up new hurdles in these areas
# = c est pourquoi nous ne nous pouvons pour rester honnetes dresser sans cesse de nouveaux obstacles dans ces domaines
# < nous pouvons donc faire des efforts pour eviter que ces nouveaux sont des obstacles <EOS>
# BLEU Score 0.027814503415066444
# NIST Score 1.232389738429133
#
# > but one thing is certain the remarkable efforts and absolute determination of the candidate countries to join the european union must be incentive enough for us to get ready and able to enlarge
# = fondamentalement il nous faut cependant considerer une chose les efforts remarquables et la volonte absolue des pays candidats a l elargissement de joindre l union europeenne doivent etre une motivation suffisante pour nous preparer nous memes a cet elargissement
# < mais il y a des progres et des efforts considerables que nous devons faire pour rejoindre l union europeenne et nous devons accueillir les pays candidats et l elargissement <EOS>
# BLEU Score 0.04100293929758851
# NIST Score 1.892672388065931
#
# > mr president we might be inclined to think that when new countries join the eu this automatically means that they will have to introduce more stringent rules to protect the environment and nature
# = monsieur le president nous avons peut etre tendance a penser que l adhesion de nouveaux etats membres suppose automatiquement que ces derniers doivent satisfaire a des normes plus strictes en matiere de protection de l environnement et de la nature
# < monsieur le president nous devrions nous attendre a ce que l ue soit plus souple dans les pays qui ne respectent pas les conditions de la pratique et de l environnement <EOS>
# BLEU Score 0.10863995577702647
# NIST Score 1.7834065392797005
#
# > mr president when pandora opened her box all the ills of mankind were released
# = monsieur le president lorsque pandore ouvrit sa boite tous les maux de l humanite furent liberes
# < monsieur le president lorsque la guerre a commence a l epoque nous avons appris a l abri de l internet <EOS>
# BLEU Score 0.14253911354181859
# NIST Score 1.2
#
# > we must begin to discuss this integrated and polycentric european development
# = il faut commencer a parler de ce developpement europeen integre et polycentrique
# < nous devons commencer par le programme europe et nous devons developper notre propre integration europeenne <EOS>
# BLEU Score 0.015718877363021206
# NIST Score 0.4779950000961542
#
# > we have just heard something about the carrot in the regional policy and promotion sector
# = nous avons entendu quelque chose sur le theme de la carotte en ce qui concerne le secteur de la politique et de la promotion regionale
# < nous avons entendu une fois de plus la volonte de la commission et du secteur de la politique regionale <EOS>
# BLEU Score 0.1633087993834332
# NIST Score 2.080545403989287
#
# > there is a series of further points which the regional committee has mentioned in its report
# = il existe une serie d autres points evoques par la commission de la politique regionale dans son rapport
# < il y a plusieurs autres points de la commission de venise a propos de ce rapport <EOS>
# BLEU Score 0.07896452734461856
# NIST Score 1.7246264642068896
#
# > if we are not to risk a repeat performance in the candidate countries it is crucial that we be clear about the fact that enlargement should not be of benefit only to men but also be of benefit to women
# = afin d eviter que le meme scenario ne se repete il est essentiel de veiller a ce que l elargissement ne profite pas seulement aux hommes mais aussi aux femmes
# < si nous ne parvenons pas a reduire les disparites entre les pays candidats il est important que nous ne soyons pas d accord pour dire que les pays candidats doivent etre consideres comme des avantages et des droits de l homme <EOS>
# BLEU Score 0.014585628855989453
# NIST Score 1.2189218671144804
#
# > as a result of the intergovernmental conference the conditions needed in order for the european union to be able to enlarge will be in place
# = des resultats de la conference intergouvernementale dependent les conditions inevitables pour que l union europeenne puisse entreprendre son elargissement
# < par consequent la conference des presidents a besoin de l elargissement de l union europeenne afin de pouvoir nous rejoindre <EOS>
# BLEU Score 0.06740258529346294
# NIST Score 1.699171005377434
#
# > the group of the greens european free alliance is calling for negotiations with the first group of countries to be completed by the end of so that the first accessions can take place before the next european elections in
# = le groupe des verts et des regionalistes plaide en faveur d une conclusion des negociations avec le premier groupe de pays candidats a la fin de afin que les premieres adhesions puissent avoir lieu avant les prochaines elections europeennes en
# < le groupe des verts alliance libre europeenne devrait enfin souhaiter la bienvenue aux negociations de l ue pour les premiers pays qui auront des lors decide de commencer a commencer par les prochaines elections europeennes <EOS>
# BLEU Score 0.1362998934293179
# NIST Score 2.138752308684218
#
# > the various reports reflect this mainstream attitude
# = les differents rapports refletent ce courant principal
# < les differents rapports sont donc en mesure de se rendre compte de l impact <EOS>
# BLEU Score 0.07069301148938888
# NIST Score 0.6015760547266295
#
# > now that you have just emerged from your former prison do not rush to enter a new one
# = a peine sortis de votre ancienne prison n entrez pas dans une nouvelle
# < aujourd hui que vous avez ete ancien ancien voisin de la nouvelle personne n a pas encore commence a se faire en prison <EOS>
# BLEU Score 0.01296247288049188
# NIST Score 0.9653321003846327
#
# > i think specifically that in going too quickly to six then to fifteen we have displayed our inability to build a europe which respects the disparities between its initial members
# = je crois precisement qu en allant deja trop vite a six puis a quinze nous avons demontre notre incapacite a construire une europe qui respecte les differences de ses premiers membres
# < je pense que tout d abord nous avons deja vecu une histoire qui a ete longue pour l europe qui nous a permis de realiser des progres dans tous les etats membres <EOS>
# BLEU Score 0.022963869978965587
# NIST Score 1.7587634601000064
#
# > we shall obtain increased competition and a more rapid process of reform in western europe too
# = nous assisterons a un renforcement de la concurrence et a une acceleration des processus de reformes y compris en europe occidentale
# < nous aurons une concurrence accrue et une plus grande ouverture de la part de l europe en vue de la reforme economique de la mondialisation <EOS>
# BLEU Score 0.02333378465831188
# NIST Score 1.5429009388670205
#
# > it is for these reasons and more importantly because of our own experience in greece that our opposition to the enlargement of the european union is meant as an expression of brotherly solidarity to the workers and people in general in the candidate countries
# = pour toutes ces raisons et partant de notre propre experience en grece notre opposition a l elargissement de l union europeenne est l expression d une solidarite fraternelle a l egard des travailleurs et en general des peuples et des pays candidats a l adhesion
# < c est pourquoi et nous avons tous les sentiments de la population de l union europeenne et de la turquie nous devons nous rejouir de l elargissement de l union europeenne et de la necessite de soutenir les pays candidats et les jeunes <EOS>
# BLEU Score 0.12965073739289243
# NIST Score 1.5894263835539224
#
# > it is imperative that the accession negotiations between romania and the union detail exactly what the romanian government needs to do to improve the standard and quality of orphanages in that country
# = il est imperatif que les negociations d adhesion entre la roumanie et l union europeenne detaillent exactement ce dont le gouvernement roumain a besoin pour ameliorer les normes et la qualite des orphelinats de ce pays
# < il est imperatif que les negociations de l ue sur la roumanie et le turkmenistan soient plus clairs dans la mesure ou je demande a la commission de fournir des informations et des conditions particulieres pour les pays en voie de developpement <EOS>
# BLEU Score 0.16508069500822653
# NIST Score 2.2446989408383047
#
# > in mr gawronski s report the commission is urged by the rapporteur among others to examine measures for furthering development and for strengthening the synergy between poland lithuania and the russian region of kaliningrad
# = dans le rapport de m gawronski la commission est par exemple invitee a etudier les mesures appropriees afin de favoriser le developpement et le renforcement de synergies entre la pologne la lituanie et la region russe de kaliningrad
# < a l article du rapport de m mitchell le rapporteur propose d accelerer la mise en uvre de la strategie de sortie de la croatie et de la promotion de la situation en republique dominicaine et de la cooperation avec la russie <EOS>
# BLEU Score 0.031952148906129636
# NIST Score 1.3317810279831885
#
# > commissioner verheugen as chairman of the committee on agriculture and rural development i took advantage of the opportunity to visit the countries that want to accede to the european union
# = monsieur verheugen en tant que president de la commission de l agriculture et du developpement rural j ai profite de l occasion pour visiter les pays candidats a l adhesion
# < le commissaire verheugen a preside a la visite de la commission et je m adresse a l avenir de l union europeenne pour aider les pays candidats a l adhesion <EOS>
# BLEU Score 0.22872196013470597
# NIST Score 2.318763760402347
#
# > the audiovisual sector is very important
# = l audiovisuel est tres important
# < le marche est donc un domaine de consultation <EOS>
# BLEU Score 0.02777619034011792
# NIST Score 0.2902410118609203
#
# > mr president today s debate concerns the major challenge at the turn of the millennium to unite europe in order to create peace and security together with social economic and environmental development
# = monsieur le president le debat d aujourd hui porte sur le grand defi de ce changement de millenaire unifier l europe pour asseoir la paix et la securite et favoriser le developpement dans les domaines social economique et environnemental
# < monsieur le president le debat de ce debat est le defi de la creation d un nouveau groupe de paix pour les citoyens europeens et le developpement durable et la securite sociale et economique <EOS>
# BLEU Score 0.16953997519068612
# NIST Score 3.1157220302125315
#
# > mr president as a member of the lithuanian delegation i would like to support the remarks made by mrs hoff in her report
# = monsieur le president en tant que membre de la delegation parlementaire mixte ue lituanie je voudrais soutenir les remarques que mme hoff a faites dans son rapport
# < en monsieur le president en tant que membre de mme morgantini je voudrais feliciter mme krehl pour son rapport sur les points de vue de la pleniere <EOS>
# BLEU Score 0.3215000448278979
# NIST Score 2.6430286692930953
#
# > blatant discrimination occurs in other countries such as poland and malta
# = des discriminations flagrantes sont commises dans d autres pays comme en pologne et a malte
# < la discrimination est importante comme la pologne la roumanie malte et les autres pays de malte et de malte <EOS>
# BLEU Score 0.028339296176052856
# NIST Score 1.233754924929006
#
# > put aside any thoughts of replacing the principle of each according to his her merits with that of each according to his her merits but not until my elections are over
# = cessez donc de vouloir remplacer le principe chacun en fonction de ses resultats par chacun en fonction de ses resultats mais mes elections d abord
# < il ne faut pas que le principe de son propre ami soit un seul etat membre mais aussi de ses merites de son propre parti et je pense que tous les jours <EOS>
# BLEU Score 0.020068932752887545
# NIST Score 0.8548730651583918
#
# > its cooperation with the international community during the kosovo conflict and its balanced role at that time are of great importance for the whole region
# = sa cooperation avec la communaute internationale durant le conflit du kosovo et son role equilibre a l epoque sont essentiels pour toute la region
# < sa cooperation internationale dans le cadre de la politique de voisinage du kosovo et de son pays a son importance a l importance de son importance a l ensemble de la region <EOS>
# BLEU Score 0.052386647673989414
# NIST Score 1.8323990804340986
#
# > it follows from this though that there must also be privatisation and restructuring of the economy
# = parmi ces efforts figurent la privatisation et la restructuration de l economie
# < il y a donc des mesures que la privatisation et la restructuration doivent etre egalement construites en pologne <EOS>
# BLEU Score 0.20105373454060027
# NIST Score 1.0023588645794062
#
# > the ignorant and the excluded cannot make up the information society they are a sure sign of its failure
# = les personnes ignorantes et exclues ne peuvent pas former une societe de l information mais sont le signe de son echec
# < la ou les et les seules personnes qui ne peuvent pas se faire l objet d une societe de l information sont elles aussi essentielles <EOS>
# BLEU Score 0.20870371467330825
# NIST Score 2.1099790296004715
#
# > member states could do more in their twinning arrangements to assist the applicant countries in developing their administrative capacity
# = les etats membres pourraient faire plus dans leurs operations jumelees pour aider les pays candidats a developper leur capacite administrative
# < les etats membres pourraient egalement aider les pays candidats a la possibilite de faciliter leurs activites de gestion des fonds <EOS>
# BLEU Score 0.30826276460621843
# NIST Score 2.166227205338418
#
# > if any area of europe is ready they are especially cyprus
# = ces regions de l europe sont fin pretes surtout chypre
# < si l europe est en jeu et a l irlande elle est particulierement proche <EOS>
# BLEU Score 0.030206205252435548
# NIST Score 0.47456115641248037
#
# > it has to be recognised that it is about joining forces economically but this can also give rise to major economic gains in the future as our market increases and there is increased growth in europe
# = l elargissement consiste en un regroupement de forces economiques il faut le reconnaitre mais ce regroupement pourra aussi produire en matiere d economie des gains importants dans l avenir en augmentant l etendue du marche et la croissance sur notre continent
# < il doit etre reconnu que les marches de l electricite peuvent etre aussi economiques mais aussi de la croissance economique et de l emploi plus forte nous devons egalement nous permettre de renforcer la croissance economique <EOS>
# BLEU Score 0.014193531680030335
# NIST Score 1.3037851110280438
#
# > mr president commissioner ladies and gentlemen we cannot afford to underestimate the importance and potential implications of this historic opportunity to unite our continent and live in peace
# = monsieur le president monsieur le commissaire mesdames et messieurs l importance et la portee de l opportunite historique qui nous est offerte d unir notre continent dans la paix ne peuvent etre ignorees
# < monsieur le president madame la commissaire mesdames et messieurs nous ne pouvons pas nous permettre de rater la chance historique et historique qui nous permettront de vivre et de vivre dans l union europeenne <EOS>
# BLEU Score 0.14380553624999495
# NIST Score 2.408170767344111
#
# > and in addition we really must see to it at the same time that the proper administrative practices are in place
# = ici il faut bien ajouter que nous devons etre prets a les appliquer au niveau administratif
# < et il faut aussi que nous soyons en mesure de les mettre en pratique <EOS>
# BLEU Score 0.039155845062422936
# NIST Score 1.3251132139617805
#
# > as vice president of our joint parliamentary committee with the czech republic i can vouch for the fact that this is true of the czech republic but i assume the same applies to a number of other states too
# = en tant que vice presidente de notre commission parlementaire mixte ue republique tcheque je sais que c est le cas en republique tcheque et je presume qu il en va de meme pour d autres pays
# < en tant que vice president de la commission de la democratie democrate tcheque je suis favorable a la position commune du conseil de l union mais aussi de la republique tcheque car il est certain que certains etats membres sont plus nombreux que ceux qui sont actuellement confrontes a ces
# BLEU Score 0.07243671671799473
# NIST Score 1.3561966681419872
#
# > the fact that there has been a reunited germany in the european union for ten years now bears witness to the solidarity between us other countries should now be given the chance to share in this even though enlargement is not just about solidarity
# = les dix annees de participation de l allemagne unifiee a l union europeenne sont pour nous une histoire de solidarite qu il faut maintenant partager avec d autres meme si l elargissement n est pas seulement une question de solidarite
# < l adhesion de la turquie a l union europeenne est un pays qui n est pas acceptable pour l union europeenne mais aussi pour les raisons qui nous ont ete aneantis pour la solidarite qui est en cours de developpement <EOS>
# BLEU Score 0.10063942569218864
# NIST Score 1.7924909121497299
#
# > on the other hand a slow pace is also an obvious problem leaving the candidate countries frustrated
# = cette tension rend le modele eee raisonne car il recompense les candidats des la periode de candidature
# < le reste est un processus lent qui est egalement lent a l egard des pays candidats a l adhesion <EOS>
# BLEU Score 0.01340082578177889
# NIST Score 0.6453888696711063
#
# > it should be made clear to all countries that accession to the european union is not quite the same thing as accession to the economic and monetary union and to the euro zone and that there are different deadlines
# = il faut dire clairement a tous les pays que l entree dans l union europeenne n entraine pas directement l entree dans l union economique et monetaire et l acces a la zone euro les delais sont differents
# < il faut maintenant que tous les pays de l union europeenne ne soient pas respectes et de l adhesion de l union europeenne a l exception de la zone euro et de l adhesion <EOS>
# BLEU Score 0.07292694711126227
# NIST Score 2.74825895187008
#
# > mr president ladies and gentlemen in his policy statement yesterday mr prodi the president of the commission said that whoever weakened any institution of the european union weakened the union as a whole
# = monsieur le president mesdames et messieurs hier le president de la commission a declare lors de son discours que celui qui affaiblit un organe de l union europeenne affaiblit l ensemble de l union europeenne
# < monsieur le president mesdames et messieurs hier a m prodi la commission prodi a declare a l unanimite la propagande politique de l union europeenne qui a ete utilise par l union europeenne qui a perdu la valeur de son propre institution <EOS>
# BLEU Score 0.2602335226500462
# NIST Score 2.4865561810431096
#
# > mr president this very day we are going to enthusiastically approve and with great interest in my case the reports on enlargement involving candidate countries such as the czech republic which is the subject of mr jurgen schroder s report
# = monsieur le president c est avec enthousiasme et pour ma part avec beaucoup d interet que nous allons approuver aujourd hui les rapports sur l elargissement aux pays candidats dont la republique tcheque a laquelle m jurgen schroder a consacre son rapport
# < monsieur le president nous sommes tres satisfaits de ce rapport et je suis favorable a l adhesion des deputes de nombreux pays candidats a l adhesion a l egard des citoyens de l union europeenne notamment en ce qui concerne le conseil de m swoboda <EOS>
# BLEU Score 0.03167596767729106
# NIST Score 1.3935068682965583
#
# ...
# NIST Score 2.2648491558343244
#
# > we will over the coming weeks have to take account of the results of the dialogue between the two political leaders or of the absence of such a dialogue
# = dans les prochaines semaines nous devrons examiner les resultats du dialogue entre les deux leaders politiques ou prendre acte de l absence d un tel dialogue
# < les prochaines elections du sommet de ce soir doivent etre prises au cours des deux semaines et que les relations politiques ne peuvent etre menees au dialogue <EOS>
# BLEU Score 0.021500003802814183
# NIST Score 1.4733316688418614
#
# > the next item is the joint debate on the following motions for resolutions
# = l ordre du jour appelle la discussion commune sur les propositions de resolution suivantes
# < l ordre du jour appelle le debat a l assemblee a propositions de resolution suivantes <EOS>
# BLEU Score 0.4121183751323027
# NIST Score 2.284412953234563
#
# > it is no coincidence that the oau and numerous african heads of state have condemned the concept of ivorian identity outright
# = et ce n est pas par hasard si l oua et de nombreux chefs d etat africains condamnent sans ambiguite l ivoirite
# < ce n est pas l etat d etat et des chefs d etat de la russie d une part l etat d epuration ethnique a ete condamne a une epoque de l epuration ethnique <EOS>
# BLEU Score 0.1103430168770977
# NIST Score 1.354521994265008
#
# > the collapse of cocoa prices the crushing weight of foreign debt and the increase in fuel prices among other factors have led to an internal situation of growing tension a notable decline in the social climate and an increase in unemployment and poverty
# = l effondrement du prix du cacao le poids ecrasant de la dette exterieure et la hausse des prix des carburants entre autres ont pousse le pays vers une situation interne marquee par des tensions croissantes une importante degradation du climat social une augmentation du chomage et de la pauvrete
# < l effondrement des prix des prix des prix des prix de l energie et des prix de l energie a augmente de l augmentation des prix de l energie et de l apartheid et de l augmentation de la pauvrete et de l augmentation des inegalites croissantes en afrique et
# BLEU Score 0.043375538000149476
# NIST Score 1.5959384208701743
#
# > we in this parliament must stand up for the rights of the people of cote d ivoire and everywhere else to a fair and properly organised democratic system with a non partisan judiciary
# = nous les deputes de ce parlement nous avons le devoir de defendre les droits du peuple de cote d ivoire et de partout ailleurs a un systeme democratique juste et correctement organise avec un pouvoir judiciaire non partisan
# < nous en avons besoin dans ce parlement et les hommes et les femmes qui ne doivent pas etre democratiques democratiques et non democratiques pour un systeme d asile <EOS>
# BLEU Score 0.01849646990927796
# NIST Score 1.3982990607633783
#
# > i want to make it clear that the commission shares parliament s view that the process of transition from military coup to elected government in cote d ivoire has fallen to put it mildly far short of the sort of democratic standards that we want to see
# = je tiens a dire clairement que la commission partage l avis du parlement selon lequel le processus de transition d un putsch militaire a un gouvernement elu en cote d ivoire est loin et c est un euphemisme des normes democratique que nous voulons voir appliquer
# < je voudrais souligner que le conseil de ministres ne voit pas l idee de la commission de l opposition a l egard de l etat de droit a l egard de l etat de droit a l egard de la democratie qui est un processus d ouverture qui est un
# BLEU Score 0.015318500535118459
# NIST Score 1.4441987391308233
#
# > as for the slanderous allusions directed at me i have to say that it is not my normal attitude and that at no time did i wish to alter the normal conduct of the debate
# = en ce qui concerne les allusions calomnieuses prononcees a mon encontre je dois dire que je n agis pas ainsi en temps normal et que je n ai voulu a aucun moment alterer le cours normal du debat
# < en ce qui concerne la parole je voudrais dire que je ne suis pas d accord avec le droit de parole et je ne pense pas que le zimbabwe soit totalement en train de se derouler dans le cas de la situation <EOS>
# BLEU Score 0.0940297729239083
# NIST Score 1.5652497126178373
#
# > it must respect the treaty and the protocol appended to the treaty states quite clearly that the twelve monthly part sessions are to be held in strasbourg
# = le parlement europeen n est pas souverain dans la fixation du calendrier
# < elle doit respecter le traite et le traite de lisbonne stipule que les pays candidats doivent etre liberes de la date de strasbourg <EOS>
# BLEU Score 0.009849349468888718
# NIST Score 0.31173586962792665
#
# > low employment of ageing workers is a matter that the european parliament should have tackled far earlier
# = le faible taux d emploi des travailleurs ages est un sujet auquel le parlement europeen aurait du s attaquer bien plus tot
# < le chomage est confronte a des travailleurs europeens qui ont ete licencies au sein de l union europeenne <EOS>
# BLEU Score 0.021753139549460215
# NIST Score 0.7893624266049741
#
# > in fact this shortage is being seized upon as an argument for increasing the pensionable age and for nipping in the bud such initiatives as there have been to lower it
# = cette penurie est meme utilisee comme argument afin de hausser l age de la retraite et de reduire a neant les amorces de reduction entamees auparavant
# < en effet ce phenomene est une menace pour l exclusion de l emploi et de la prostitution forcee de la creation d emplois qui a ete lancee <EOS>
# BLEU Score 0.024826065966265493
# NIST Score 1.247423734150067
#
# > their valuable contribution to our society is hugely neglected in this report
# = le present rapport ignore largement leur precieuse contribution a la societe
# < leur contribution a notre societe est donc tres importante <EOS>
# BLEU Score 0.04829027362797447
# NIST Score 1.2974413576745663
#
# > mr president the commission communication is i think a milestone in the history of social policy because it marks the end of a period in which senior citizens were seen as a generation of outcasts or veterans
# = monsieur le president la communication de la commission constitue je pense une etape importante dans l histoire de la politique sociale car elle met fin a une periode ou l evocation du troisieme age se faisait en considerant celui ci comme la generation des desherites ou des invalides
# < monsieur le president la commission est en train de se rappeler que la revolution de la revolution est une occasion historique qui a ete cree a l epoque de la periode de decision qui a ete prise en consideration et a l epoque <EOS>
# BLEU Score 0.08109942685661345
# NIST Score 1.8561504450651238
#
# > as the markets are only interested in young people and their purchasing power it falls to politicians to attend to the issue of older people
# = vu que les marches ne s interessent qu aux jeunes et a leur pouvoir d achat les affaires concernant les personnes agees restent du ressort de la politique
# < comme les peuples les seuls sont les hommes et les femmes qui se trouvent dans le monde qui se trouvent dans un choix de leurs electeurs <EOS>
# BLEU Score 0.010060559285741328
# NIST Score 0.7246361846183855
#
# > this is a miscalculation considering the current and future demographic situation and also considering the fact that today s working population will be tomorrow s non working population in economic terms
# = c est un mauvais calcul compte tenu de la situation demographique actuelle et a venir et compte tenu aussi que les actifs d aujourd hui sont les inactifs de demain en termes economiques
# < cela signifie que la situation actuelle et la situation demographique economique actuelle ne peut etre consideree comme une semaine de demain a la population de l union europeenne <EOS>
# BLEU Score 0.044679018468137134
# NIST Score 1.5451937785041079
#
# > the fact that people are discriminated against on the grounds of age was of course confirmed in my report on article which i was able to present to the house in october
# = l article du rapport que j ai soumis au parlement au mois d octobre confirme que l on pratique une discrimination liee a l age
# < le fait que les personnes handicapees aient ete enregistrees dans l union europeenne ont ete enregistrees dans le rapport de la directive je me suis prononce en faveur de la declaration de ce jour <EOS>
# BLEU Score 0.007205335066302803
# NIST Score 0.3337237079000888
#
# > i do not necessarily think that all women should go out to work either because we are after all calling for the labour force penetration rate of women to be increased through changes in family and tax policy
# = de plus je ne desire a tout prix que toutes les femmes soient actives car nous voulons plutot que la participation des femmes au monde du travail soit renforcee par une politique familiale et fiscale
# < je ne pense pas que tous les travailleurs soient plus politiques doivent etre reelus car nous devons continuer a travailler en faveur de la politique salariale de la directive sur les salaires et les salaires des travailleurs <EOS>
# BLEU Score 0.020501078627328556
# NIST Score 1.9137827631683657
#
# > what is more age related issues are amongst the most important objectives setting the agenda in the new process of cooperation in the field of social protection
# = le probleme du vieillissement fait partie des objectifs les plus importants qui determinent le nouveau processus de cooperation dans le domaine de la protection sociale
# < ce qui est plus important que les autres groupes de la question de la mise en uvre du nouveau cadre de developpement de la vie sociale <EOS>
# BLEU Score 0.022379352592750163
# NIST Score 1.5705656041527891
#
# > we shall now proceed to the vote
# = nous passons au vote
# < l assemblee a egalement vote les factures d emission <EOS>
# BLEU Score 0.023980296761827107
# NIST Score 0.2222222222222222
#
# > this approach is a welcome one and is similar to that already employed to promote agricultural products in third countries
# = cette demarche est tout a fait souhaitable a l instar de ce qui se fait deja pour la promotion de produits agricoles dans les pays tiers
# < cette approche est un signe et je suis d accord avec les pays tiers qui sont egalement des produits agricoles en provenance de l ue <EOS>
# BLEU Score 0.053868277983054956
# NIST Score 1.8282798798030553
#
# > perhaps this fact will instil a spirit of unanimity in us which would doubtless knowing the great heartedness of the commission lead it to accept all our amendments
# = il pourrait vous conduire a une unanimite qui sans doute connaissant la grandeur d ame de la commission la conduirait a accepter la totalite de nos amendements
# < cela peut etre une bonne chose que nous puissions faire preuve de fermete dans la position de la commission qui sera totalement unanime en adoptant une nouvelle proposition de compromis <EOS>
# BLEU Score 0.03819633968206938
# NIST Score 1.0129220263668783
#
# > obviously this represents a great opportunity for rural areas because the physical distance separating them from the large centres will become insignificant and new opportunities are emerging which at the end of the day need to be taken
# = il s agit evidemment d une opportunite importante pour le monde rural qui precisement comblera ainsi la distance qui le separe des grands centres et de nouvelles possibilites voient le jour qui en fin de compte vaudront certainement la peine d etre prises en consideration
# < il est evident que la region peut etre consideree comme une source de vie limitee aux zones rurales qui sont les plus importantes et les plus importantes qui ne sont pas encore en cours de vie <EOS>
# BLEU Score 0.007142257915174003
# NIST Score 1.0751872291168596
#
# > we now hope that parliament will fall in line with them across the board and i of course urge my own group to give you its complete support
# = nous esperons maintenant que ce parlement va les suivre tres largement et naturellement j invite mon groupe a vous soutenir totalement
# < nous esperons que le parlement et le conseil sont tous tres fermes et je suis tout a fait d accord avec vous pour soutenir cette initiative <EOS>
# BLEU Score 0.022379352592750163
# NIST Score 1.5204175694234172
#
# > the practice of mixing a fat into calf feed which comes from meat meal production which in any case is highly dubious given the risk of bse transmission creates in my opinion a centre of infection for young animals
# = le fait que pour les veaux nous ajoutions de la graisse provenant de la fabrication des farines animales ce qui est manifestement tres suspect eu egard a la transmission de la maladie de la vache folle constitue un autre foyer de contamination pour les jeunes animaux
# < la graisse des farines animales a l origine de farines animales est une source de risques pour la propagation de la viande de volaille qui est tres importante pour les animaux de l elevage de betail <EOS>
# BLEU Score 0.04088529210516796
# NIST Score 1.9753576807605733
#
# > the system of sales promotion measures is part of what is wrong with the system for the eu s agricultural policy
# = le systeme des actions de promotion est l un des elements du dysfonctionnement de la politique agricole de l ue
# < le systeme de subventions de l ue est une des mesures qui sont liees au developpement de la politique agricole <EOS>
# BLEU Score 0.2076047003130265
# NIST Score 2.4748822187422603
#
# > i sincerely hope that it is not anyone s ideological view of what is safe and right that will be put forward but information with a proper scientific basis
# = j espere sincerement que ce qui sera propose ne sera pas un quelconque point de vue ideologique de ce qui sain et sur mais qu il s agira d informations basees sur des donnees scientifiques adequate
# < j espere que ce n est pas un point de vue ideologique mais il ne peut donc etre possible de la qualite de la vie et de la qualite de l ethique <EOS>
# BLEU Score 0.10605315301524489
# NIST Score 2.227724075089685
#
# > this concept of thematic information provision and promotional measures complementing national and regional measures requires strong commitment on the part of the member states in the form of co financing and support for administering and monitoring the measures to be implemented
# = le concept de mesures d information et de promotion commerciale qui completent les mesures nationales requiert un engagement fort de la part des etats membres par l intermediaire du cofinancement et du controle de mesures a prendre
# < ce programme d action de l ue et des mesures speciales pour les mesures speciales de soutien aux autorites regionales et aux etats membres doivent etre coordonnees et ciblees et les mesures de soutien et de soutien a l utilisation de la part des etats membres doivent etre mis en
# BLEU Score 0.13131510825423057
# NIST Score 1.6750565934521964
#
# > i appear to be the last speaker in the year although not by design
# = sans le rechercher il semble que je vais etre le dernier orateur de l an
# < je pense que l on ne peut pas se resumer a l autre et non de l eau <EOS>
# BLEU Score 0.027166383723579154
# NIST Score 0.8681979101352264
#
# > please think of the extra few seconds that i gave you mrs lulling as your christmas present
# = considerez madame lulling que les secondes supplementaires que je vous ai donnees sont votre cadeau de noel
# < je voudrais vous dire quelques secondes que dix secondes m verheugen a vu que mme noel a ete le premier a la presidence espagnole <EOS>
# BLEU Score 0.012384901282810543
# NIST Score 0.9385323769792516
#
# > i can fully concur with the view taken by my colleague mr jan mulder in this respect
# = je me rallie pleinement a la contribution de notre collegue liberal jan mulder
# < je partage totalement mon avis dans ce domaine comme m mulder a egalement evoque cette question <EOS>
# BLEU Score 0.01618861356572822
# NIST Score 0.6938324471514548
#
# Average BLEU Score: 0.06994883127986416
# Average NIST Score: 1.352494710821054
# Total skipped sentences: 31

# %% [markdown]
# ### Single Sentence Evaluation
#
# One may wish to enter their own sentence (one that contains the words used during training) for inference. You should use lowercase without any punctuation.

# %%
sentence = "mr president ladies and gentlemen in his policy statement yesterday mr prodi the president of the commission said that whoever weakened any institution of the european union weakened the union as a whole"

decoder_output, _ = evaluate(encoder, decoder, sentence, model["input_lang"], model["output_lang"])
output_sentence = " ".join(decoder_output)
print(output_sentence)
# Out:
# monsieur le president mesdames et messieurs hier a m prodi la commission prodi a declare a l unanimite la propagande politique de l union europeenne qui a ete utilise par l union europeenne qui a perdu la valeur de son propre institution <EOS>
